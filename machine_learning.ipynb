# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
train = pd.read_csv('/Users/Janey_jiayan/Downloads/Humana_Data/train.csv')

# %%
train = train.drop(train.columns[[0]], axis=1)

# %%
train.head()
# Out:
#               ID  FullPaidClaim  InbCallMbr  InbCallProv  CAD  Diabetes  \
# 0  ID10010854159             43          26            8    0         0
# 1  ID10010854159             88          44            8    1         1
# 2  ID10013863216             19           2            1    0         0
# 3  ID10024447278             21          18            0    0         0
# 4   ID1002482139            149           6            5    1         1
#
#    Hypertension  CPD  CHF  Surgery  AvgSpentSurgery   TotalFPC  TotalCAD  \
# 0             0    0    0        1          2314.00   23227.94       0.0
# 1             0    0    0        1          2314.00   36439.87     125.0
# 2             0    0    0        1         12337.42   18282.46       0.0
# 3             0    0    0        0              NaN    3126.90       0.0
# 4             0    1    0        1         50042.33  136843.88     137.0
#
#    TotalCHF  TotalDiabetes  TotalHypertension  TotalCPD  TotalMME  \
# ...

# %%
train = train.fillna(0)

# %%
train.shape
# Out:
# (23100, 21)

# %%
train['LTOT'] = train['LTOT'] + 0

# %%
pd.options.display.max_columns = 50
train.head(5)
# Out:
#               ID  FullPaidClaim  InbCallMbr  InbCallProv  CAD  Diabetes  \
# 0  ID10010854159             43          26            8    0         0
# 1  ID10010854159             88          44            8    1         1
# 2  ID10013863216             19           2            1    0         0
# 3  ID10024447278             21          18            0    0         0
# 4   ID1002482139            149           6            5    1         1
#
#    Hypertension  CPD  CHF  Surgery  AvgSpentSurgery   TotalFPC  TotalCAD  \
# 0             0    0    0        1          2314.00   23227.94       0.0
# 1             0    0    0        1          2314.00   36439.87     125.0
# 2             0    0    0        1         12337.42   18282.46       0.0
# 3             0    0    0        0             0.00    3126.90       0.0
# 4             0    1    0        1         50042.33  136843.88     137.0
#
#    TotalCHF  TotalDiabetes  TotalHypertension  TotalCPD  TotalMME  \
# ...

# %% [markdown]
# ### split data to train and valid

# %%
Y = train.pop('LTOT')

# %%
Y[:5]
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    1
# Name: LTOT, dtype: int64

# %%
X = train.drop('ID', axis=1)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, test_size=0.33, random_state=100)

# %%
X_train.head()
# Out:
#        FullPaidClaim  InbCallMbr  InbCallProv  CAD  Diabetes  Hypertension  \
# 1414              40           0           17    0         0             0
# 11327             70           3            5    0         0             1
# 10061             25           0            1    0         0             0
# 21173             62          25            0    0         0             1
# 11038             58           7            5    0         0             1
#
#        CPD  CHF  Surgery  AvgSpentSurgery   TotalFPC  TotalCAD  TotalCHF  \
# 1414     0    0        0             0.00   30866.76       0.0       0.0
# 11327    0    0        0             0.00  109094.70       0.0       0.0
# 10061    0    0        0             0.00    8120.13       0.0       0.0
# 21173    0    0        1          1170.00  118971.30       0.0       0.0
# 11038    1    0        3         15234.96   32177.16       0.0       0.0
#
# ...

# %% [markdown]
# ##### Build xgboost model
